# %%
import importlib
import clustering

from sklearn.cluster import KMeans

data_file_path = "data/dataset.csv"

# %%
importlib.reload(clustering)
clusterator = clustering.Clusterator(data_file_path)
model = KMeans(n_clusters=3, random_state=311)
columns = ["price", "room_type", "minimum_nights", "number_of_reviews", "reviews_per_month", "calculated_host_listings_count", "availability_365", "rating", "popularity", "beds"]
clusterator.clusterize(model=model, columns=columns)
clusterator.plot(show_values="price")
# clusterator.pca_plot(model=model, columns=columns, )
# Out:
# Values of column price:
#    cluster   min     max        mean
# 0        0  29.0  9994.0  240.704706
# 1        1  10.0   500.0   97.228137
# 2        2  20.0  7314.0  166.327980

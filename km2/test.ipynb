# %%
import clustering
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids

# %%
file_name = "data/dataset.csv"
model = KMedoids(5)

data = clustering.Clusterator(file_name=file_name)
fig, axs = plt.subplots(2, 3, figsize=(15,10))
for i, ax in enumerate(axs.flatten()):
    model = KMeans(i+2)
    scatter = data.clusterize(columns=["latitude", "longitude"], model=model, ax=ax)
plt.tight_layout()
plt.show()

# %%
data.clusterize(columns=["latitude", "longitude"], model=KMeans(4))
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>
